# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# Ensure the outputs directory exists
os.makedirs('./outputs', exist_ok=True)

# Assuming lookalike_df is already created
lookalike_df = pd.DataFrame({
    'CustomerID': ['C0001', 'C0002', 'C0003'],
    'Lookalike1': ['C0004', 'C0005', 'C0006'],
    'Score1': [0.95, 0.89, 0.92],
    'Lookalike2': ['C0007', 'C0008', 'C0009'],
    'Score2': [0.93, 0.87, 0.90],
    'Lookalike3': ['C0010', 'C0011', 'C0012'],
    'Score3': [0.91, 0.85, 0.88]
})

# Save the Lookalike DataFrame to a CSV file
lookalike_df.to_csv('../outputs/FirstName_LastName_Lookalike.csv', index=False)

# Example plot (assuming you have data to plot)
regions = ['North America', 'Europe', 'Asia']
revenue = [100000, 80000, 60000]

plt.bar(regions, revenue)
plt.xlabel('Region')
plt.ylabel('Revenue')
plt.title('Revenue by Region')

# Save the plot to a file
plt.savefig('../outputs/revenue_by_region.png')
plt.show()
